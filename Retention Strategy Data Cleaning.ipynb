# %%
import pandas as pd

df = pd.read_csv("Desktop/SQL Project May/Dataset.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
print(df.columns.tolist())
# Out:
# ['customer_id', 'age', 'gender', 'item_purchased', 'category', 'purchase_amount', 'location', 'size', 'color', 'season', 'review_rating', 'subscription_status', 'shipping_type', 'discount_applied', 'promo_code_used', 'previous_purchases', 'payment_method', 'frequency_of_purchases', 'promo_dependency', 'frequency', 'value_score', 'loyalty_v1', 'loyalty_v2', 'satisfaction_flag', 'value_tier', 'promo_segment']

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_')
)

# %%
df = df.rename(columns={'purchase_amount_(usd)': 'purchase_amount'})

# %%
df['promo_dependency'] = df['discount_applied'].map({'Yes': 1, 'No': 0})

# %%
freq_map = {
    'Weekly': 52,
    'Fortnightly': 26,
    'Monthly': 12,
    'Quarterly': 4,
    'Annually': 1
}

df['frequency'] = df['frequency_of_purchases'].map(freq_map)

# %%
df['value_score'] = (
    df['purchase_amount'] * 0.5 +
    df['previous_purchases'] * 0.3 +
    df['frequency'] * 0.2
)

# %%
df['loyalty_v1'] = df['frequency'] * (1 - df['promo_dependency'])

# %%
df['loyalty_v2'] = df['purchase_amount'] * df['previous_purchases']

# %%
df['satisfaction_flag'] = df['review_rating'] > 4

# %%
import pandas as pd

df['value_tier'] = pd.qcut(
    df['purchase_amount'],
    q=3,
    labels=['Low', 'Medium', 'High']
)

# %%
def promo_segment(x):
    if x == 1:
        return 'Discount Buyer'
    else:
        return 'Organic Buyer'

df['promo_segment'] = df['promo_dependency'].apply(promo_segment)

# %%
df.head()
df.describe()
df['promo_segment'].value_counts()
# Out:
# promo_segment
# Organic Buyer     2223
# Discount Buyer    1677
# Name: count, dtype: int64
